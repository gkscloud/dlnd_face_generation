# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 5

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    inputs_real = tf.placeholder(tf.float32, (None, image_height, image_width, image_channels), name="inputs_real")
    inputs_z = tf.placeholder(tf.float32, (None,z_dim), name="inputs_z")
    learning_rate = tf.placeholder(tf.float32, name="learning_rate")

    return inputs_real, inputs_z, learning_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    
    #parameters
    kernel_size = 4
    alpha = 0.2
    
#     print("images_shape:", images.shape)
    
    with tf.variable_scope("discriminator", reuse=reuse) as discriminator_scope:
        #input shape is 28x28x5
        input_layer1 = tf.layers.conv2d(images, 64, kernel_size, strides=2, padding='same')
        relu1 = tf.maximum(alpha * input_layer1, input_layer1) 
        #shape is now 14x14x64
        
        input_layer2 = tf.layers.conv2d(input_layer1, 128, kernel_size, strides=2, padding='same')
        batch_norm2 = tf.layers.batch_normalization(input_layer2, training=True)
        relu2 = tf.maximum(alpha * batch_norm2, batch_norm2)
        #shape is now 7x7x128
        
        input_layer3 = tf.layers.conv2d(input_layer2, 256, kernel_size, strides=1, padding='same')
        batch_norm3 = tf.layers.batch_normalization(input_layer3, training=True)
        relu3 = tf.maximum(alpha * batch_norm3, batch_norm3) 
#         shape is now 7x7x256
        
#         input_layer4 = tf.layers.conv2d(input_layer3, 512, kernel_size, strides=1, padding='same')
#         batch_norm4 = tf.layers.batch_normalization(input_layer4, training=True)
#         relu4 = tf.maximum(alpha * batch_norm4, batch_norm4) 
        
        #flatten?
#         flat = tf.reshape(relu3,(-1,28*28*256))
        flat = tf.reshape(relu3,(-1,7*7*256))
        logits = tf.layers.dense(flat,1)
        out = tf.sigmoid(logits)
        
    return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    alpha = 0.2 
    kernel_size = 4
    
#     print("z.shape", z.get_shape())
    
    with tf.variable_scope('generator', reuse=not(is_train)):
#         x1 = tf.layers.dense(z,7*7*512)
        x1 = tf.layers.dense(z,7*7*512)

        #reshape for the conv network
        x1 = tf.reshape(x1, (-1, 7,7,512))
        x1 = tf.layers.batch_normalization(x1, training=is_train)
        x1 = tf.maximum(alpha * x1, x1)
#         print("x1", x1.get_shape())
        
        x2 = tf.layers.conv2d_transpose(x1, 256,kernel_size, strides=2, padding='same')
        x2 = tf.layers.batch_normalization(x2, training=is_train)
        x2 = tf.maximum(alpha * x2, x2)
#         print("x2", x2.get_shape())
    
        x3 = tf.layers.conv2d_transpose(x2, 128,kernel_size, strides=2, padding='same')
        x3 = tf.layers.batch_normalization(x3, training=is_train)
        x3 = tf.maximum(alpha * x3, x3)
    
        x4 = tf.layers.conv2d_transpose(x3, 128,kernel_size, strides=1, padding='same')
        x4 = tf.layers.batch_normalization(x4, training=is_train)
        x4 = tf.maximum(alpha * x4, x4)
#         print("x3", x3.get_shape())

#         x5 = tf.layers.conv2d_transpose(x4, 64,kernel_size, strides=1, padding='same')
#         x5 = tf.layers.batch_normalization(x5, training=is_train)
#         x5 = tf.maximum(alpha * x5, x5)

#         x4 = tf.layers.conv2d_transpose(x3, 128,kernel_size, strides=1, padding='same')
#         x4 = tf.layers.batch_normalization(x4, training=is_train)
#         x4 = tf.maximum(alpha * x4, x4)
        
        #output
        logits = tf.layers.conv2d_transpose(x4, out_channel_dim, kernel_size, strides=1, padding='same')
#         print("logits", logits.get_shape())
        
        out = tf.tanh(logits)
        
    
        return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    #implementing pattern described in deep-leraning/dcgan-svhn model_loss
    generator_object = generator(input_z, out_channel_dim, True)
    discriminator_model_real, discriminator_logits_real = discriminator(input_real)
    discriminator_model_fake, discriminator_logits_fake = discriminator(generator_object, reuse=True)
    
    discriminator_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=discriminator_logits_real, labels=tf.ones_like(discriminator_model_real)))
    discriminator_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=discriminator_logits_fake, labels=tf.zeros_like(discriminator_model_fake)))
    generator_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=discriminator_logits_fake, labels=tf.ones_like(discriminator_model_fake)))
    
    discriminator_loss = discriminator_loss_real + discriminator_loss_fake
    
    return discriminator_loss, generator_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # get weights and biases variables to update
    training_variables = tf.trainable_variables()
    d_variables = [v for v in training_variables if v.name.startswith("discriminator")]
    g_variables = [v for v in training_variables if v.name.startswith("generator")]
    
    #optimization
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_variables)
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_variables)
    
    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import pickle as pkl

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()
    
    with open('samples.pkl', 'wb') as f:
        pkl.dump(samples, f)

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    #model inputs
    _, img_width, img_height, img_channels = data_shape
    inputs_real, inputs_z, lr = model_inputs(img_width,img_height,img_channels, z_dim)
    #calc loss
    d_loss, g_loss = model_loss(inputs_real, inputs_z,img_channels)
    d_opt, g_opt = model_opt(d_loss, g_loss, learning_rate, beta1)
    
    saver = tf.train.Saver()
    
    losses = []
    batch_count = 0
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
#                 print("batch_images shape: ", batch_images.shape)
                x = batch_images*2
                batch_count += 1
#                 print("Running epoch:",epoch_i+1, " batch: ", batch_count)
                
                batch_z = np.random.uniform(-1,1,size=(batch_size,z_dim))
                
                # run optimizers
                _ = sess.run(d_opt, feed_dict={inputs_real: x, inputs_z: batch_z})
                _ = sess.run(g_opt, feed_dict={inputs_z: batch_z, inputs_real: x})
                
                if(batch_count % 10 == 0):
                    train_loss_d = d_loss.eval({inputs_real: x, inputs_z: batch_z})
                    train_loss_g = g_loss.eval({inputs_z: batch_z})
                    
                    print("Epoch {}/{}...".format(epoch_i+1, epoch_count),
                          "Discriminator Loss: {:.6f}...".format(train_loss_d),
                          "Generator Loss: {:.6f}".format(train_loss_g))
                    losses.append((train_loss_d, train_loss_g))
                    
                if (batch_count % 100 == 0):
                    show_generator_output(sess, 25, inputs_z, img_channels, data_image_mode)
                
            saver.save(sess, './checkpoints/generator.ckpt')

    return losses

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.00002
beta1 = 0.75


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

tf.reset_default_graph()

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 1.565556... Generator Loss: 0.387992
# Epoch 1/2... Discriminator Loss: 1.139008... Generator Loss: 0.675788
# Epoch 1/2... Discriminator Loss: 1.358525... Generator Loss: 0.474058
# Epoch 1/2... Discriminator Loss: 1.791690... Generator Loss: 0.326093
# Epoch 1/2... Discriminator Loss: 0.998519... Generator Loss: 0.934475
# Epoch 1/2... Discriminator Loss: 1.625706... Generator Loss: 0.355187
# Epoch 1/2... Discriminator Loss: 1.406968... Generator Loss: 0.480170
# Epoch 1/2... Discriminator Loss: 0.772472... Generator Loss: 0.945989
# Epoch 1/2... Discriminator Loss: 0.822251... Generator Loss: 0.843209
# Epoch 1/2... Discriminator Loss: 1.466832... Generator Loss: 0.494296
# Epoch 1/2... Discriminator Loss: 1.481597... Generator Loss: 0.534234
# Epoch 1/2... Discriminator Loss: 1.535011... Generator Loss: 0.458158
# Epoch 1/2... Discriminator Loss: 1.507500... Generator Loss: 0.407122
# Epoch 1/2... Discriminator Loss: 1.350710... Generator Loss: 0.731136
# Epoch 1/2... Discriminator Loss: 1.335699... Generator Loss: 0.821143
# Epoch 1/2... Discriminator Loss: 1.487548... Generator Loss: 0.579809
# Epoch 1/2... Discriminator Loss: 1.763911... Generator Loss: 0.600394
# Epoch 1/2... Discriminator Loss: 1.615634... Generator Loss: 0.758454
# Epoch 1/2... Discriminator Loss: 1.305895... Generator Loss: 0.763462
# Epoch 1/2... Discriminator Loss: 1.770613... Generator Loss: 0.691272
# Epoch 1/2... Discriminator Loss: 1.630309... Generator Loss: 0.639442
# Epoch 1/2... Discriminator Loss: 1.530440... Generator Loss: 0.648333
# Epoch 1/2... Discriminator Loss: 1.489175... Generator Loss: 0.803263
# Epoch 1/2... Discriminator Loss: 1.409581... Generator Loss: 0.747152
# Epoch 1/2... Discriminator Loss: 1.576769... Generator Loss: 0.749408
# Epoch 1/2... Discriminator Loss: 1.433892... Generator Loss: 0.676612
# Epoch 1/2... Discriminator Loss: 1.496445... Generator Loss: 0.748101
# Epoch 1/2... Discriminator Loss: 1.193258... Generator Loss: 0.865302
# Epoch 1/2... Discriminator Loss: 1.700573... Generator Loss: 0.600914
# Epoch 1/2... Discriminator Loss: 1.377919... Generator Loss: 0.763355
# Epoch 1/2... Discriminator Loss: 1.452414... Generator Loss: 0.696725
# Epoch 1/2... Discriminator Loss: 1.465580... Generator Loss: 0.718359
# Epoch 1/2... Discriminator Loss: 1.428379... Generator Loss: 0.702674
# Epoch 1/2... Discriminator Loss: 1.469529... Generator Loss: 0.696494
# Epoch 1/2... Discriminator Loss: 1.378812... Generator Loss: 0.719681
# Epoch 1/2... Discriminator Loss: 1.387171... Generator Loss: 0.736559
# Epoch 1/2... Discriminator Loss: 1.393108... Generator Loss: 0.711759
# Epoch 1/2... Discriminator Loss: 1.490317... Generator Loss: 0.656188
# Epoch 1/2... Discriminator Loss: 1.497649... Generator Loss: 0.643309
# Epoch 1/2... Discriminator Loss: 1.499259... Generator Loss: 0.663787
# Epoch 1/2... Discriminator Loss: 1.527400... Generator Loss: 0.649095
# Epoch 1/2... Discriminator Loss: 1.521148... Generator Loss: 0.659308
# Epoch 1/2... Discriminator Loss: 1.516457... Generator Loss: 0.633032
# Epoch 1/2... Discriminator Loss: 1.557103... Generator Loss: 0.645521
# Epoch 1/2... Discriminator Loss: 1.437908... Generator Loss: 0.678622
# Epoch 1/2... Discriminator Loss: 1.477694... Generator Loss: 0.690441
# Epoch 2/2... Discriminator Loss: 1.439327... Generator Loss: 0.684555
# Epoch 2/2... Discriminator Loss: 1.490699... Generator Loss: 0.657533
# Epoch 2/2... Discriminator Loss: 1.563921... Generator Loss: 0.638512
# Epoch 2/2... Discriminator Loss: 1.510294... Generator Loss: 0.646908
# Epoch 2/2... Discriminator Loss: 1.423586... Generator Loss: 0.673976
# Epoch 2/2... Discriminator Loss: 1.461900... Generator Loss: 0.667400
# Epoch 2/2... Discriminator Loss: 1.550918... Generator Loss: 0.661734
# Epoch 2/2... Discriminator Loss: 1.406108... Generator Loss: 0.720807
# Epoch 2/2... Discriminator Loss: 1.374087... Generator Loss: 0.699973
# Epoch 2/2... Discriminator Loss: 1.518777... Generator Loss: 0.655894
# Epoch 2/2... Discriminator Loss: 1.479471... Generator Loss: 0.657852
# Epoch 2/2... Discriminator Loss: 1.446180... Generator Loss: 0.712041
# Epoch 2/2... Discriminator Loss: 1.405142... Generator Loss: 0.711315
# Epoch 2/2... Discriminator Loss: 1.419317... Generator Loss: 0.702109
# Epoch 2/2... Discriminator Loss: 1.421332... Generator Loss: 0.694287
# Epoch 2/2... Discriminator Loss: 1.390469... Generator Loss: 0.708838
# Epoch 2/2... Discriminator Loss: 1.421594... Generator Loss: 0.718477
# Epoch 2/2... Discriminator Loss: 1.404878... Generator Loss: 0.700552
# Epoch 2/2... Discriminator Loss: 1.478097... Generator Loss: 0.656756
# Epoch 2/2... Discriminator Loss: 1.410134... Generator Loss: 0.719820
# Epoch 2/2... Discriminator Loss: 1.388640... Generator Loss: 0.736512
# Epoch 2/2... Discriminator Loss: 1.464511... Generator Loss: 0.687644
# Epoch 2/2... Discriminator Loss: 1.473315... Generator Loss: 0.661719
# Epoch 2/2... Discriminator Loss: 1.385599... Generator Loss: 0.717290
# Epoch 2/2... Discriminator Loss: 1.391774... Generator Loss: 0.727899
# Epoch 2/2... Discriminator Loss: 1.442115... Generator Loss: 0.728079
# Epoch 2/2... Discriminator Loss: 1.497223... Generator Loss: 0.646119
# Epoch 2/2... Discriminator Loss: 1.450065... Generator Loss: 0.682146
# Epoch 2/2... Discriminator Loss: 1.405464... Generator Loss: 0.708455
# Epoch 2/2... Discriminator Loss: 1.318192... Generator Loss: 0.747330
# Epoch 2/2... Discriminator Loss: 1.492830... Generator Loss: 0.646815
# Epoch 2/2... Discriminator Loss: 1.550855... Generator Loss: 0.643067
# Epoch 2/2... Discriminator Loss: 1.351561... Generator Loss: 0.729267
# Epoch 2/2... Discriminator Loss: 1.361419... Generator Loss: 0.731085
# Epoch 2/2... Discriminator Loss: 1.469151... Generator Loss: 0.672153
# Epoch 2/2... Discriminator Loss: 1.558846... Generator Loss: 0.620176
# Epoch 2/2... Discriminator Loss: 1.372316... Generator Loss: 0.727075
# Epoch 2/2... Discriminator Loss: 1.248420... Generator Loss: 0.822793
# Epoch 2/2... Discriminator Loss: 1.309870... Generator Loss: 0.756058
# Epoch 2/2... Discriminator Loss: 1.537404... Generator Loss: 0.656333
# Epoch 2/2... Discriminator Loss: 1.417709... Generator Loss: 0.720185
# Epoch 2/2... Discriminator Loss: 1.242529... Generator Loss: 0.798997
# Epoch 2/2... Discriminator Loss: 1.302102... Generator Loss: 0.757297
# Epoch 2/2... Discriminator Loss: 1.454842... Generator Loss: 0.660514
# Epoch 2/2... Discriminator Loss: 1.534123... Generator Loss: 0.629666
# Epoch 2/2... Discriminator Loss: 1.335706... Generator Loss: 0.795301
# Epoch 2/2... Discriminator Loss: 1.317108... Generator Loss: 0.750914

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.00002
beta1 = 0.75


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 1.879944... Generator Loss: 0.238614
# Epoch 1/1... Discriminator Loss: 1.534229... Generator Loss: 0.343204
# Epoch 1/1... Discriminator Loss: 1.964291... Generator Loss: 0.224253
# Epoch 1/1... Discriminator Loss: 1.824488... Generator Loss: 0.273065
# Epoch 1/1... Discriminator Loss: 1.686393... Generator Loss: 0.316467
# Epoch 1/1... Discriminator Loss: 1.896464... Generator Loss: 0.231467
# Epoch 1/1... Discriminator Loss: 1.915455... Generator Loss: 0.255307
# Epoch 1/1... Discriminator Loss: 1.583645... Generator Loss: 0.383319
# Epoch 1/1... Discriminator Loss: 1.716572... Generator Loss: 0.315575
# Epoch 1/1... Discriminator Loss: 1.597056... Generator Loss: 0.395879
# Epoch 1/1... Discriminator Loss: 1.158733... Generator Loss: 0.674735
# Epoch 1/1... Discriminator Loss: 1.422910... Generator Loss: 0.513514
# Epoch 1/1... Discriminator Loss: 1.215212... Generator Loss: 0.711694
# Epoch 1/1... Discriminator Loss: 1.155169... Generator Loss: 0.741746
# Epoch 1/1... Discriminator Loss: 1.247631... Generator Loss: 0.735858
# Epoch 1/1... Discriminator Loss: 1.288135... Generator Loss: 0.730381
# Epoch 1/1... Discriminator Loss: 1.217329... Generator Loss: 0.805387
# Epoch 1/1... Discriminator Loss: 1.266595... Generator Loss: 0.871705
# Epoch 1/1... Discriminator Loss: 1.220718... Generator Loss: 0.974896
# Epoch 1/1... Discriminator Loss: 1.183451... Generator Loss: 0.963565
# Epoch 1/1... Discriminator Loss: 1.246232... Generator Loss: 0.990878
# Epoch 1/1... Discriminator Loss: 1.127089... Generator Loss: 0.996389
# Epoch 1/1... Discriminator Loss: 1.053569... Generator Loss: 1.030857
# Epoch 1/1... Discriminator Loss: 1.187257... Generator Loss: 1.082012
# Epoch 1/1... Discriminator Loss: 1.140496... Generator Loss: 1.025189
# Epoch 1/1... Discriminator Loss: 1.142012... Generator Loss: 0.978312
# Epoch 1/1... Discriminator Loss: 1.098469... Generator Loss: 0.943497
# Epoch 1/1... Discriminator Loss: 1.217209... Generator Loss: 0.802580
# Epoch 1/1... Discriminator Loss: 1.194958... Generator Loss: 0.809787
# Epoch 1/1... Discriminator Loss: 1.424525... Generator Loss: 0.798613
# Epoch 1/1... Discriminator Loss: 1.376430... Generator Loss: 0.892158
# Epoch 1/1... Discriminator Loss: 1.317433... Generator Loss: 0.806726
# Epoch 1/1... Discriminator Loss: 1.423173... Generator Loss: 0.775180
# Epoch 1/1... Discriminator Loss: 1.399962... Generator Loss: 0.811692
# Epoch 1/1... Discriminator Loss: 1.499211... Generator Loss: 0.747215
# Epoch 1/1... Discriminator Loss: 1.458021... Generator Loss: 0.851025
# Epoch 1/1... Discriminator Loss: 1.512653... Generator Loss: 0.681573
# Epoch 1/1... Discriminator Loss: 1.580687... Generator Loss: 0.664539
# Epoch 1/1... Discriminator Loss: 1.444340... Generator Loss: 0.758049
# Epoch 1/1... Discriminator Loss: 1.677238... Generator Loss: 0.779721
# Epoch 1/1... Discriminator Loss: 1.576918... Generator Loss: 0.731109
# Epoch 1/1... Discriminator Loss: 1.762667... Generator Loss: 0.613620
# Epoch 1/1... Discriminator Loss: 1.466135... Generator Loss: 0.723508
# Epoch 1/1... Discriminator Loss: 1.626567... Generator Loss: 0.733616
# Epoch 1/1... Discriminator Loss: 1.611392... Generator Loss: 0.675695
# Epoch 1/1... Discriminator Loss: 1.555740... Generator Loss: 0.746353
# Epoch 1/1... Discriminator Loss: 1.497731... Generator Loss: 0.702619
# Epoch 1/1... Discriminator Loss: 1.782643... Generator Loss: 0.635428
# Epoch 1/1... Discriminator Loss: 1.570192... Generator Loss: 0.636942
# Epoch 1/1... Discriminator Loss: 1.563797... Generator Loss: 0.693212
# Epoch 1/1... Discriminator Loss: 1.667864... Generator Loss: 0.655072
# Epoch 1/1... Discriminator Loss: 1.736459... Generator Loss: 0.641466
# Epoch 1/1... Discriminator Loss: 1.700864... Generator Loss: 0.579527
# Epoch 1/1... Discriminator Loss: 1.569551... Generator Loss: 0.734469
# Epoch 1/1... Discriminator Loss: 1.888125... Generator Loss: 0.598064
# Epoch 1/1... Discriminator Loss: 1.638742... Generator Loss: 0.694326
# Epoch 1/1... Discriminator Loss: 1.620452... Generator Loss: 0.666979
# Epoch 1/1... Discriminator Loss: 1.729213... Generator Loss: 0.638208
# Epoch 1/1... Discriminator Loss: 1.742650... Generator Loss: 0.584088
# Epoch 1/1... Discriminator Loss: 1.812381... Generator Loss: 0.563003
# Epoch 1/1... Discriminator Loss: 1.667626... Generator Loss: 0.671320
# Epoch 1/1... Discriminator Loss: 1.686128... Generator Loss: 0.622383
# Epoch 1/1... Discriminator Loss: 1.750279... Generator Loss: 0.574049
# Epoch 1/1... Discriminator Loss: 1.623509... Generator Loss: 0.621912
# Epoch 1/1... Discriminator Loss: 1.596514... Generator Loss: 0.637159
# Epoch 1/1... Discriminator Loss: 1.697599... Generator Loss: 0.581352
# Epoch 1/1... Discriminator Loss: 1.743473... Generator Loss: 0.553829
# Epoch 1/1... Discriminator Loss: 1.643224... Generator Loss: 0.634645
# Epoch 1/1... Discriminator Loss: 1.699656... Generator Loss: 0.634850
# Epoch 1/1... Discriminator Loss: 1.678952... Generator Loss: 0.626784
# Epoch 1/1... Discriminator Loss: 1.647094... Generator Loss: 0.615631
# Epoch 1/1... Discriminator Loss: 1.684907... Generator Loss: 0.587570
# Epoch 1/1... Discriminator Loss: 1.648067... Generator Loss: 0.645513
# Epoch 1/1... Discriminator Loss: 1.663867... Generator Loss: 0.647367
# Epoch 1/1... Discriminator Loss: 1.713426... Generator Loss: 0.592732
# Epoch 1/1... Discriminator Loss: 1.588774... Generator Loss: 0.638915
# Epoch 1/1... Discriminator Loss: 1.638924... Generator Loss: 0.627636
# Epoch 1/1... Discriminator Loss: 1.634069... Generator Loss: 0.634184
# Epoch 1/1... Discriminator Loss: 1.529743... Generator Loss: 0.649311
# Epoch 1/1... Discriminator Loss: 1.640812... Generator Loss: 0.652666
# Epoch 1/1... Discriminator Loss: 1.598721... Generator Loss: 0.652765
# Epoch 1/1... Discriminator Loss: 1.581504... Generator Loss: 0.621643
# Epoch 1/1... Discriminator Loss: 1.507833... Generator Loss: 0.679260
# Epoch 1/1... Discriminator Loss: 1.559575... Generator Loss: 0.629732
# Epoch 1/1... Discriminator Loss: 1.604015... Generator Loss: 0.581870
# Epoch 1/1... Discriminator Loss: 1.460953... Generator Loss: 0.737325
# Epoch 1/1... Discriminator Loss: 1.536683... Generator Loss: 0.672919
# Epoch 1/1... Discriminator Loss: 1.473835... Generator Loss: 0.637195
# Epoch 1/1... Discriminator Loss: 1.556340... Generator Loss: 0.669233
# Epoch 1/1... Discriminator Loss: 1.661449... Generator Loss: 0.629434
# Epoch 1/1... Discriminator Loss: 1.455901... Generator Loss: 0.666820
# Epoch 1/1... Discriminator Loss: 1.649421... Generator Loss: 0.593946
# Epoch 1/1... Discriminator Loss: 1.502849... Generator Loss: 0.721571
# Epoch 1/1... Discriminator Loss: 1.541330... Generator Loss: 0.699772
# Epoch 1/1... Discriminator Loss: 1.663374... Generator Loss: 0.524505
# Epoch 1/1... Discriminator Loss: 1.636494... Generator Loss: 0.627311
# Epoch 1/1... Discriminator Loss: 1.636002... Generator Loss: 0.657975
# Epoch 1/1... Discriminator Loss: 1.692740... Generator Loss: 0.533092
# Epoch 1/1... Discriminator Loss: 1.704038... Generator Loss: 0.558815
# Epoch 1/1... Discriminator Loss: 1.607005... Generator Loss: 0.618036
# Epoch 1/1... Discriminator Loss: 1.562973... Generator Loss: 0.596802
# Epoch 1/1... Discriminator Loss: 1.628103... Generator Loss: 0.625686
# Epoch 1/1... Discriminator Loss: 1.547575... Generator Loss: 0.650579
# Epoch 1/1... Discriminator Loss: 1.516442... Generator Loss: 0.647224
# Epoch 1/1... Discriminator Loss: 1.680063... Generator Loss: 0.612838
# Epoch 1/1... Discriminator Loss: 1.589216... Generator Loss: 0.635626
# Epoch 1/1... Discriminator Loss: 1.573450... Generator Loss: 0.628850
# Epoch 1/1... Discriminator Loss: 1.619230... Generator Loss: 0.586249
# Epoch 1/1... Discriminator Loss: 1.549761... Generator Loss: 0.653614
# Epoch 1/1... Discriminator Loss: 1.547407... Generator Loss: 0.639265
# Epoch 1/1... Discriminator Loss: 1.620808... Generator Loss: 0.600838
# Epoch 1/1... Discriminator Loss: 1.587782... Generator Loss: 0.618023
# Epoch 1/1... Discriminator Loss: 1.592467... Generator Loss: 0.615419
# Epoch 1/1... Discriminator Loss: 1.624342... Generator Loss: 0.605478
# Epoch 1/1... Discriminator Loss: 1.506958... Generator Loss: 0.682665
# Epoch 1/1... Discriminator Loss: 1.588409... Generator Loss: 0.657347
# Epoch 1/1... Discriminator Loss: 1.668296... Generator Loss: 0.618390
# Epoch 1/1... Discriminator Loss: 1.580173... Generator Loss: 0.619210
# Epoch 1/1... Discriminator Loss: 1.562614... Generator Loss: 0.597520
# Epoch 1/1... Discriminator Loss: 1.563667... Generator Loss: 0.617488
# Epoch 1/1... Discriminator Loss: 1.559608... Generator Loss: 0.661478
# Epoch 1/1... Discriminator Loss: 1.566004... Generator Loss: 0.659779
# Epoch 1/1... Discriminator Loss: 1.621670... Generator Loss: 0.615788
# Epoch 1/1... Discriminator Loss: 1.552128... Generator Loss: 0.625701
# Epoch 1/1... Discriminator Loss: 1.527742... Generator Loss: 0.662150
# Epoch 1/1... Discriminator Loss: 1.582528... Generator Loss: 0.595215
# Epoch 1/1... Discriminator Loss: 1.580413... Generator Loss: 0.608333
# Epoch 1/1... Discriminator Loss: 1.568981... Generator Loss: 0.607891
# Epoch 1/1... Discriminator Loss: 1.549899... Generator Loss: 0.629184
# Epoch 1/1... Discriminator Loss: 1.576907... Generator Loss: 0.651651
# Epoch 1/1... Discriminator Loss: 1.544338... Generator Loss: 0.629465
# Epoch 1/1... Discriminator Loss: 1.596031... Generator Loss: 0.602831
# Epoch 1/1... Discriminator Loss: 1.513928... Generator Loss: 0.646667
# Epoch 1/1... Discriminator Loss: 1.578080... Generator Loss: 0.633716
# Epoch 1/1... Discriminator Loss: 1.535377... Generator Loss: 0.638369
# Epoch 1/1... Discriminator Loss: 1.505020... Generator Loss: 0.676164
# Epoch 1/1... Discriminator Loss: 1.597513... Generator Loss: 0.619612
# Epoch 1/1... Discriminator Loss: 1.588239... Generator Loss: 0.633203
# Epoch 1/1... Discriminator Loss: 1.513399... Generator Loss: 0.642781
# Epoch 1/1... Discriminator Loss: 1.526710... Generator Loss: 0.630719
# Epoch 1/1... Discriminator Loss: 1.537395... Generator Loss: 0.649775
# Epoch 1/1... Discriminator Loss: 1.560618... Generator Loss: 0.644486
# Epoch 1/1... Discriminator Loss: 1.603779... Generator Loss: 0.629559
# Epoch 1/1... Discriminator Loss: 1.600058... Generator Loss: 0.631040
# Epoch 1/1... Discriminator Loss: 1.541916... Generator Loss: 0.685340
# Epoch 1/1... Discriminator Loss: 1.446627... Generator Loss: 0.678345
# Epoch 1/1... Discriminator Loss: 1.573127... Generator Loss: 0.640408
# Epoch 1/1... Discriminator Loss: 1.561405... Generator Loss: 0.594963
# Epoch 1/1... Discriminator Loss: 1.551091... Generator Loss: 0.640548
# Epoch 1/1... Discriminator Loss: 1.544814... Generator Loss: 0.627322
# Epoch 1/1... Discriminator Loss: 1.494143... Generator Loss: 0.667697
# Epoch 1/1... Discriminator Loss: 1.479951... Generator Loss: 0.679155
# Epoch 1/1... Discriminator Loss: 1.580867... Generator Loss: 0.634139
# Epoch 1/1... Discriminator Loss: 1.588771... Generator Loss: 0.630902
# Epoch 1/1... Discriminator Loss: 1.500924... Generator Loss: 0.672197
# Epoch 1/1... Discriminator Loss: 1.520934... Generator Loss: 0.606690
# Epoch 1/1... Discriminator Loss: 1.512622... Generator Loss: 0.646260
# Epoch 1/1... Discriminator Loss: 1.479255... Generator Loss: 0.638086

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
